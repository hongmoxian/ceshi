# %% [markdown]
# ###### 2023/7/6
# * 看文献准备晚上的讨论
# * 以后要学习使用markdown的语法记录笔记
# -----
# 1. [第一条](#第一条)
# 2. [第二条](#第二条)
# 3. [第三条](#第三条)
#
# ------
# ![这是一双鞋](https://picx.zhimg.com/80/v2-c923b72265499ed5c26260efc2a9fcfd_720w.webp?source=1940ef5c)
#
# ----------
# **粗体**<br>
# *斜体*<br>
# ~删除~<br>
#
# -----
# ***独显这是独显***
#
# * 一级列表
# * 二级列表
#     1. 二级列表
#     2. 二级列表
#
# [zhihu超链接](https://www.zhihu.com/)
#
# # 第一条
# -----
#
# # 第二条
# ----
#
# # 第三条
# 这是一条测试的语句

# %% [markdown]
# **额外一种插入图片的方法**
# ![WeChat%20Image_20230107234420.jpg](attachment:WeChat%20Image_20230107234420.jpg)

# %% [markdown]
# # 2023/7/7
# -----
# 1. [看文献，找到合适的模型准备初始末态结构](#文献)
# 2. [看github上workspace的用法，在线运行项目和**push** 和 **commit** 文件](#文件)
# 3. 看电催化的文献
# 4. 学习vasp的基本操作
# 5. 学习的过程中需要保持心情愉快，不然很难受的，而且状态不好心里难受。
# 6. vscode 是神器，需要好好学习。
# ----
#
# # 文献
# -----
#
#
#
# ---
# # 文件
#
#
#
#
# ----

# %% [markdown]
# # 2023/7/10
# ----
# - 学习vasp的基本操作
# - 看恒电势和电催化的文献
# - 整理邮寄物品
# - 晚饭后去看房子
# - 多看网上视频，多学习（任重而道远）
# - 学习占据数矩阵
# - 看知乎上的电催化的基本知识
# - 等有新机器了学习matminer的基本操作，学习机器学习
# - 学习量子力学等基础知识，理解一些基本算法和怎么使用计算机编写。
# ---

# %% [markdown]
# # 2023/7/12
# ----
# - 看文献（PRL，搞清楚氧化还原势和HOMO和LOMO的关系）
# - 看知乎上关于MP上爬材料和机器学习的代码和例子
# - 多学习
# ----

# %% [markdown]
# # 2023/7/13
# ----
# - 看文献（PRL，搞清楚氧化还原势和HOMO和LOMO的关系）
# - 看知乎上关于MP上爬材料和机器学习的代码和例子
# - 多学习
# ----
# ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# # 2023/7/16
# ----
# - 怎么使用GPU
# - mpirun的-n 和-np的区别
# - 安装好deepmd-kit训练数据集，完成ai4ec的初赛内容
# ---
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2023/7/17
# ----
# - CUDA_VISIBLE_DEVICES=GPU的使用，多显卡上提交任务
# - 看文献，看学习视频，掌握新知识
# - 完成ai4ec的初赛内容
# ---
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2023/7/19
# ----
# - CUDA_VISIBLE_DEVICES=GPU的使用，多显卡上提交任务
# - 看文献，看学习视频，掌握新知识
# - 理解lammps的输入文件的语法，并且在服务器上跑通
# - 放松状态
# ---
# ![image.png](attachment:image.png)
